# %%
from pckt import *
from fitting import RockSat_1_14_fitting_functions as fit

# %%
path = f'~/DAPPEr/data/UDIP4/json/UDIP_4_800s.json'
iv = pck(path, 200, "Full").iv

# %%
fit.gen_fit(iv['V'], iv['I0'])
# Out:
# (array([-6.7005132 , -6.47337716, -6.24624112, -6.01910507, -5.79196903,
#         -5.56483299, -5.33769695, -5.11056091, -4.88342487, -4.65628883,
#         -4.42915279, -4.20201675, -3.97488071, -3.74774467, -3.52060863,
#         -3.29347259, -3.06633655, -2.83920051, -2.61206447, -2.38492843,
#         -2.15779239, -1.93065634, -1.7035203 , -1.47638426, -1.24924822,
#         -1.02211218, -0.79497614, -0.5678401 , -0.34070406, -0.11356802,
#          0.11356802,  0.34070406,  0.5678401 ,  0.79497614,  1.02211218,
#          1.24924822,  1.47638426,  1.7035203 ,  1.93065634,  2.15779239,
#          2.38492843,  2.61206447,  2.83920051,  3.06633655,  3.29347259,
#          3.52060863,  3.74774467,  3.97488071,  4.20201675,  4.42915279,
#          4.65628883,  4.88342487,  5.11056091,  5.33769695,  5.56483299,
#          5.79196903,  6.01910507,  6.24624112,  6.47337716,  6.7005132 ]),
#  array([ 3.45202640e-05,  3.34995771e-05,  3.24788901e-05,  3.14582031e-05,
# ...

# %%
from pckt import *
path = f'~/DAPPEr/data/UDIP4/json/UDIP_4_800s.json'

# %%
iv = pck(path, num = 230, sw_type = 'Full').iv

# %%
plt.plot(iv['V'], iv['I0'])

# %%
iv.to_csv('iv_230.csv', sep = ',', columns = ['V', 'I0'], float_format= np.float64, index = False, header = False)

# %%
np.array([2,5,2])
# Out:
# array([2, 5, 2])
